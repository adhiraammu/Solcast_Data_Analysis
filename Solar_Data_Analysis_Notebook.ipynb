# %% [markdown]
# # Extracting Solar data using Rest Api from 'Solcast'

# %% [markdown]
# ## Step 1 - Importing and requesting data from api

# %%
import requests

url = "https://solcast.p.rapidapi.com/radiation/forecasts"

querystring = {"api_key":"Your Api key","latitude":"42.3601","longitude":"-71.0589","format":"json"}

headers = {#headers}

response = requests.request("GET", url, headers=headers, params=querystring).json()

response
# Out:
# {'forecasts': [{'ghi': 286,
#    'ghi90': 353,
#    'ghi10': 250,
#    'ebh': 111,
#    'dni': 288,
#    'dni10': 115,
#    'dni90': 690,
#    'dhi': 175,
#    'air_temp': 1,
#    'zenith': 68,
#    'azimuth': -118,
#    'cloud_opacity': 24,
#    'period_end': '2023-03-12T13:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 434,
#    'ghi90': 464,
#    'ghi10': 329,
#    'ebh': 327,
#    'dni': 715,
#    'dni10': 203,
#    'dni90': 891,
#    'dhi': 107,
#    'air_temp': 2,
#    'zenith': 63,
#    'azimuth': -124,
#    'cloud_opacity': 7,
#    'period_end': '2023-03-12T14:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 544,
#    'ghi90': 544,
#    'ghi10': 461,
#    'ebh': 480,
#    'dni': 923,
#    'dni10': 519,
#    'dni90': 923,
#    'dhi': 64,
#    'air_temp': 2,
#    'zenith': 59,
#    'azimuth': -131,
#    'cloud_opacity': 0,
#    'period_end': '2023-03-12T14:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 614,
#    'ghi90': 614,
#    'ghi10': 570,
#    'ebh': 547,
#    'dni': 948,
#    'dni10': 747,
#    'dni90': 948,
#    'dhi': 67,
#    'air_temp': 3,
#    'zenith': 55,
#    'azimuth': -139,
#    'cloud_opacity': 0,
#    'period_end': '2023-03-12T15:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 668,
#    'ghi90': 671,
#    'ghi10': 552,
#    'ebh': 595,
#    'dni': 954,
#    'dni10': 493,
#    'dni90': 966,
#    'dhi': 73,
#    'air_temp': 3,
#    'zenith': 51,
#    'azimuth': -147,
#    'cloud_opacity': 0,
#    'period_end': '2023-03-12T15:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 683,
#    'ghi90': 715,
#    'ghi10': 498,
#    'ebh': 560,
#    'dni': 850,
#    'dni10': 216,
#    'dni90': 978,
#    'dhi': 123,
#    'air_temp': 4,
#    'zenith': 49,
#    'azimuth': -157,
#    'cloud_opacity': 4,
#    'period_end': '2023-03-12T16:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 677,
#    'ghi90': 743,
#    'ghi10': 476,
#    'ebh': 499,
#    'dni': 731,
#    'dni10': 116,
#    'dni90': 986,
#    'dhi': 179,
#    'air_temp': 4,
#    'zenith': 47,
#    'azimuth': -166,
#    'cloud_opacity': 9,
#    'period_end': '2023-03-12T16:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 670,
#    'ghi90': 756,
#    'ghi10': 417,
#    'ebh': 461,
#    'dni': 666,
#    'dni10': 0,
#    'dni90': 989,
#    'dhi': 209,
#    'air_temp': 4,
#    'zenith': 46,
#    'azimuth': -177,
#    'cloud_opacity': 11,
#    'period_end': '2023-03-12T17:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 662,
#    'ghi90': 754,
#    'ghi10': 406,
#    'ebh': 445,
#    'dni': 645,
#    'dni10': 0,
#    'dni90': 988,
#    'dhi': 217,
#    'air_temp': 5,
#    'zenith': 46,
#    'azimuth': 173,
#    'cloud_opacity': 12,
#    'period_end': '2023-03-12T17:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 638,
#    'ghi90': 736,
#    'ghi10': 376,
#    'ebh': 413,
#    'dni': 611,
#    'dni10': 0,
#    'dni90': 981,
#    'dhi': 226,
#    'air_temp': 5,
#    'zenith': 48,
#    'azimuth': 163,
#    'cloud_opacity': 13,
#    'period_end': '2023-03-12T18:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 612,
#    'ghi90': 703,
#    'ghi10': 344,
#    'ebh': 397,
#    'dni': 612,
#    'dni10': 0,
#    'dni90': 971,
#    'dhi': 215,
#    'air_temp': 5,
#    'zenith': 50,
#    'azimuth': 153,
#    'cloud_opacity': 13,
#    'period_end': '2023-03-12T18:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 583,
#    'ghi90': 655,
#    'ghi10': 311,
#    'ebh': 399,
#    'dni': 654,
#    'dni10': 0,
#    'dni90': 957,
#    'dhi': 185,
#    'air_temp': 5,
#    'zenith': 52,
#    'azimuth': 144,
#    'cloud_opacity': 11,
#    'period_end': '2023-03-12T19:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 533,
#    'ghi90': 593,
#    'ghi10': 269,
#    'ebh': 369,
#    'dni': 658,
#    'dni10': 0,
#    'dni90': 937,
#    'dhi': 164,
#    'air_temp': 5,
#    'zenith': 56,
#    'azimuth': 136,
#    'cloud_opacity': 10,
#    'period_end': '2023-03-12T19:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 457,
#    'ghi90': 520,
#    'ghi10': 223,
#    'ebh': 293,
#    'dni': 586,
#    'dni10': 0,
#    'dni90': 909,
#    'dhi': 163,
#    'air_temp': 5,
#    'zenith': 60,
#    'azimuth': 129,
#    'cloud_opacity': 12,
#    'period_end': '2023-03-12T20:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 376,
#    'ghi90': 436,
#    'ghi10': 177,
#    'ebh': 224,
#    'dni': 521,
#    'dni10': 0,
#    'dni90': 870,
#    'dhi': 152,
#    'air_temp': 5,
#    'zenith': 65,
#    'azimuth': 122,
#    'cloud_opacity': 14,
#    'period_end': '2023-03-12T20:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 291,
#    'ghi90': 344,
#    'ghi10': 130,
#    'ebh': 157,
#    'dni': 445,
#    'dni10': 0,
#    'dni90': 817,
#    'dhi': 134,
#    'air_temp': 4,
#    'zenith': 69,
#    'azimuth': 116,
#    'cloud_opacity': 15,
#    'period_end': '2023-03-12T21:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 202,
#    'ghi90': 248,
#    'ghi10': 83,
#    'ebh': 89,
#    'dni': 328,
#    'dni10': 0,
#    'dni90': 738,
#    'dhi': 113,
#    'air_temp': 4,
#    'zenith': 74,
#    'azimuth': 110,
#    'cloud_opacity': 19,
#    'period_end': '2023-03-12T21:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 109,
#    'ghi90': 150,
#    'ghi10': 41,
#    'ebh': 21,
#    'dni': 111,
#    'dni10': 0,
#    'dni90': 617,
#    'dhi': 88,
#    'air_temp': 4,
#    'zenith': 80,
#    'azimuth': 105,
#    'cloud_opacity': 28,
#    'period_end': '2023-03-12T22:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 38,
#    'ghi90': 60,
#    'ghi10': 12,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 360,
#    'dhi': 38,
#    'air_temp': 3,
#    'zenith': 85,
#    'azimuth': 99,
#    'cloud_opacity': 38,
#    'period_end': '2023-03-12T22:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 2,
#    'ghi90': 4,
#    'ghi10': 1,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 15,
#    'dhi': 2,
#    'air_temp': 3,
#    'zenith': 91,
#    'azimuth': 94,
#    'cloud_opacity': 48,
#    'period_end': '2023-03-12T23:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 96,
#    'azimuth': 89,
#    'cloud_opacity': 54,
#    'period_end': '2023-03-12T23:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 102,
#    'azimuth': 84,
#    'cloud_opacity': 58,
#    'period_end': '2023-03-13T00:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 107,
#    'azimuth': 79,
#    'cloud_opacity': 60,
#    'period_end': '2023-03-13T00:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 113,
#    'azimuth': 73,
#    'cloud_opacity': 61,
#    'period_end': '2023-03-13T01:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 118,
#    'azimuth': 67,
#    'cloud_opacity': 61,
#    'period_end': '2023-03-13T01:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 123,
#    'azimuth': 61,
#    'cloud_opacity': 62,
#    'period_end': '2023-03-13T02:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 127,
#    'azimuth': 54,
#    'cloud_opacity': 63,
#    'period_end': '2023-03-13T02:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 132,
#    'azimuth': 46,
#    'cloud_opacity': 64,
#    'period_end': '2023-03-13T03:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 135,
#    'azimuth': 37,
#    'cloud_opacity': 65,
#    'period_end': '2023-03-13T03:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 138,
#    'azimuth': 27,
#    'cloud_opacity': 65,
#    'period_end': '2023-03-13T04:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 140,
#    'azimuth': 15,
#    'cloud_opacity': 66,
#    'period_end': '2023-03-13T04:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 141,
#    'azimuth': 4,
#    'cloud_opacity': 66,
#    'period_end': '2023-03-13T05:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 141,
#    'azimuth': -8,
#    'cloud_opacity': 67,
#    'period_end': '2023-03-13T05:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 140,
#    'azimuth': -20,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-13T06:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 137,
#    'azimuth': -30,
#    'cloud_opacity': 69,
#    'period_end': '2023-03-13T06:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 134,
#    'azimuth': -40,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-13T07:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 130,
#    'azimuth': -49,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-13T07:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 126,
#    'azimuth': -56,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-13T08:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 121,
#    'azimuth': -63,
#    'cloud_opacity': 71,
#    'period_end': '2023-03-13T08:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 116,
#    'azimuth': -69,
#    'cloud_opacity': 72,
#    'period_end': '2023-03-13T09:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 111,
#    'azimuth': -75,
#    'cloud_opacity': 72,
#    'period_end': '2023-03-13T09:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 105,
#    'azimuth': -81,
#    'cloud_opacity': 72,
#    'period_end': '2023-03-13T10:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 100,
#    'azimuth': -86,
#    'cloud_opacity': 72,
#    'period_end': '2023-03-13T10:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 94,
#    'azimuth': -91,
#    'cloud_opacity': 72,
#    'period_end': '2023-03-13T11:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 4,
#    'ghi90': 7,
#    'ghi10': 3,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 4,
#    'air_temp': 3,
#    'zenith': 89,
#    'azimuth': -96,
#    'cloud_opacity': 72,
#    'period_end': '2023-03-13T11:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 25,
#    'ghi90': 38,
#    'ghi10': 16,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 25,
#    'air_temp': 3,
#    'zenith': 83,
#    'azimuth': -101,
#    'cloud_opacity': 71,
#    'period_end': '2023-03-13T12:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 62,
#    'ghi90': 89,
#    'ghi10': 40,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 62,
#    'air_temp': 3,
#    'zenith': 78,
#    'azimuth': -106,
#    'cloud_opacity': 66,
#    'period_end': '2023-03-13T12:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 107,
#    'ghi90': 149,
#    'ghi10': 73,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 107,
#    'air_temp': 4,
#    'zenith': 72,
#    'azimuth': -112,
#    'cloud_opacity': 61,
#    'period_end': '2023-03-13T13:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 157,
#    'ghi90': 211,
#    'ghi10': 111,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 157,
#    'air_temp': 4,
#    'zenith': 67,
#    'azimuth': -118,
#    'cloud_opacity': 58,
#    'period_end': '2023-03-13T13:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 208,
#    'ghi90': 272,
#    'ghi10': 151,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 3,
#    'dhi': 208,
#    'air_temp': 5,
#    'zenith': 63,
#    'azimuth': -124,
#    'cloud_opacity': 55,
#    'period_end': '2023-03-13T14:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 250,
#    'ghi90': 324,
#    'ghi10': 184,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 20,
#    'dhi': 250,
#    'air_temp': 5,
#    'zenith': 58,
#    'azimuth': -131,
#    'cloud_opacity': 53,
#    'period_end': '2023-03-13T14:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 285,
#    'ghi90': 366,
#    'ghi10': 214,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 29,
#    'dhi': 285,
#    'air_temp': 6,
#    'zenith': 54,
#    'azimuth': -139,
#    'cloud_opacity': 53,
#    'period_end': '2023-03-13T15:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 321,
#    'ghi90': 402,
#    'ghi10': 246,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 40,
#    'dhi': 321,
#    'air_temp': 6,
#    'zenith': 51,
#    'azimuth': -147,
#    'cloud_opacity': 52,
#    'period_end': '2023-03-13T15:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 350,
#    'ghi90': 429,
#    'ghi10': 271,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 45,
#    'dhi': 350,
#    'air_temp': 6,
#    'zenith': 48,
#    'azimuth': -157,
#    'cloud_opacity': 50,
#    'period_end': '2023-03-13T16:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 374,
#    'ghi90': 452,
#    'ghi10': 295,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 61,
#    'dhi': 374,
#    'air_temp': 6,
#    'zenith': 47,
#    'azimuth': -166,
#    'cloud_opacity': 49,
#    'period_end': '2023-03-13T16:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 392,
#    'ghi90': 470,
#    'ghi10': 316,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 84,
#    'dhi': 392,
#    'air_temp': 6,
#    'zenith': 46,
#    'azimuth': -177,
#    'cloud_opacity': 47,
#    'period_end': '2023-03-13T17:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 389,
#    'ghi90': 467,
#    'ghi10': 315,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 83,
#    'dhi': 389,
#    'air_temp': 6,
#    'zenith': 46,
#    'azimuth': 173,
#    'cloud_opacity': 47,
#    'period_end': '2023-03-13T17:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 366,
#    'ghi90': 444,
#    'ghi10': 294,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 56,
#    'dhi': 366,
#    'air_temp': 7,
#    'zenith': 47,
#    'azimuth': 163,
#    'cloud_opacity': 49,
#    'period_end': '2023-03-13T18:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 336,
#    'ghi90': 411,
#    'ghi10': 268,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 24,
#    'dhi': 336,
#    'air_temp': 7,
#    'zenith': 49,
#    'azimuth': 153,
#    'cloud_opacity': 51,
#    'period_end': '2023-03-13T18:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 300,
#    'ghi90': 369,
#    'ghi10': 239,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 1,
#    'dhi': 300,
#    'air_temp': 6,
#    'zenith': 52,
#    'azimuth': 144,
#    'cloud_opacity': 53,
#    'period_end': '2023-03-13T19:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 259,
#    'ghi90': 319,
#    'ghi10': 204,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 259,
#    'air_temp': 6,
#    'zenith': 56,
#    'azimuth': 136,
#    'cloud_opacity': 55,
#    'period_end': '2023-03-13T19:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 219,
#    'ghi90': 266,
#    'ghi10': 172,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 219,
#    'air_temp': 6,
#    'zenith': 60,
#    'azimuth': 129,
#    'cloud_opacity': 57,
#    'period_end': '2023-03-13T20:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 175,
#    'ghi90': 212,
#    'ghi10': 137,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 175,
#    'air_temp': 6,
#    'zenith': 64,
#    'azimuth': 122,
#    'cloud_opacity': 58,
#    'period_end': '2023-03-13T20:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 126,
#    'ghi90': 155,
#    'ghi10': 98,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 126,
#    'air_temp': 6,
#    'zenith': 69,
#    'azimuth': 116,
#    'cloud_opacity': 62,
#    'period_end': '2023-03-13T21:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 82,
#    'ghi90': 103,
#    'ghi10': 64,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 82,
#    'air_temp': 5,
#    'zenith': 74,
#    'azimuth': 110,
#    'cloud_opacity': 65,
#    'period_end': '2023-03-13T21:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 44,
#    'ghi90': 56,
#    'ghi10': 34,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 44,
#    'air_temp': 5,
#    'zenith': 80,
#    'azimuth': 104,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-13T22:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 16,
#    'ghi90': 20,
#    'ghi10': 12,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 16,
#    'air_temp': 5,
#    'zenith': 85,
#    'azimuth': 99,
#    'cloud_opacity': 72,
#    'period_end': '2023-03-13T22:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 1,
#    'ghi90': 1,
#    'ghi10': 1,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 1,
#    'air_temp': 5,
#    'zenith': 90,
#    'azimuth': 94,
#    'cloud_opacity': 71,
#    'period_end': '2023-03-13T23:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 96,
#    'azimuth': 89,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-13T23:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 101,
#    'azimuth': 84,
#    'cloud_opacity': 69,
#    'period_end': '2023-03-14T00:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 107,
#    'azimuth': 78,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-14T00:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 112,
#    'azimuth': 73,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-14T01:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 118,
#    'azimuth': 67,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-14T01:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 123,
#    'azimuth': 60,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-14T02:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 127,
#    'azimuth': 53,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-14T02:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 131,
#    'azimuth': 45,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-14T03:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 135,
#    'azimuth': 36,
#    'cloud_opacity': 69,
#    'period_end': '2023-03-14T03:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 138,
#    'azimuth': 26,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-14T04:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 140,
#    'azimuth': 15,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-14T04:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 141,
#    'azimuth': 4,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-14T05:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 140,
#    'azimuth': -8,
#    'cloud_opacity': 72,
#    'period_end': '2023-03-14T05:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 139,
#    'azimuth': -20,
#    'cloud_opacity': 73,
#    'period_end': '2023-03-14T06:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 137,
#    'azimuth': -30,
#    'cloud_opacity': 75,
#    'period_end': '2023-03-14T06:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 134,
#    'azimuth': -40,
#    'cloud_opacity': 77,
#    'period_end': '2023-03-14T07:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 130,
#    'azimuth': -48,
#    'cloud_opacity': 78,
#    'period_end': '2023-03-14T07:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 125,
#    'azimuth': -56,
#    'cloud_opacity': 79,
#    'period_end': '2023-03-14T08:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 121,
#    'azimuth': -63,
#    'cloud_opacity': 80,
#    'period_end': '2023-03-14T08:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 116,
#    'azimuth': -69,
#    'cloud_opacity': 81,
#    'period_end': '2023-03-14T09:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 110,
#    'azimuth': -75,
#    'cloud_opacity': 81,
#    'period_end': '2023-03-14T09:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 105,
#    'azimuth': -80,
#    'cloud_opacity': 81,
#    'period_end': '2023-03-14T10:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 99,
#    'azimuth': -86,
#    'cloud_opacity': 81,
#    'period_end': '2023-03-14T10:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 94,
#    'azimuth': -91,
#    'cloud_opacity': 81,
#    'period_end': '2023-03-14T11:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 3,
#    'ghi90': 4,
#    'ghi10': 3,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 3,
#    'air_temp': 4,
#    'zenith': 88,
#    'azimuth': -96,
#    'cloud_opacity': 81,
#    'period_end': '2023-03-14T11:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 18,
#    'ghi90': 22,
#    'ghi10': 14,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 18,
#    'air_temp': 4,
#    'zenith': 83,
#    'azimuth': -101,
#    'cloud_opacity': 80,
#    'period_end': '2023-03-14T12:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 39,
#    'ghi90': 50,
#    'ghi10': 29,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 39,
#    'air_temp': 4,
#    'zenith': 77,
#    'azimuth': -106,
#    'cloud_opacity': 79,
#    'period_end': '2023-03-14T12:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 53,
#    'ghi90': 75,
#    'ghi10': 36,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 53,
#    'air_temp': 4,
#    'zenith': 72,
#    'azimuth': -112,
#    'cloud_opacity': 80,
#    'period_end': '2023-03-14T13:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 68,
#    'ghi90': 104,
#    'ghi10': 39,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 68,
#    'air_temp': 4,
#    'zenith': 67,
#    'azimuth': -118,
#    'cloud_opacity': 82,
#    'period_end': '2023-03-14T13:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 84,
#    'ghi90': 138,
#    'ghi10': 37,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 84,
#    'air_temp': 4,
#    'zenith': 62,
#    'azimuth': -124,
#    'cloud_opacity': 82,
#    'period_end': '2023-03-14T14:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 90,
#    'ghi90': 165,
#    'ghi10': 31,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 90,
#    'air_temp': 4,
#    'zenith': 58,
#    'azimuth': -131,
#    'cloud_opacity': 83,
#    'period_end': '2023-03-14T14:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 90,
#    'ghi90': 187,
#    'ghi10': 24,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 90,
#    'air_temp': 4,
#    'zenith': 54,
#    'azimuth': -139,
#    'cloud_opacity': 85,
#    'period_end': '2023-03-14T15:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 100,
#    'ghi90': 225,
#    'ghi10': 20,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 100,
#    'air_temp': 4,
#    'zenith': 51,
#    'azimuth': -147,
#    'cloud_opacity': 85,
#    'period_end': '2023-03-14T15:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 122,
#    'ghi90': 274,
#    'ghi10': 21,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 122,
#    'air_temp': 4,
#    'zenith': 48,
#    'azimuth': -156,
#    'cloud_opacity': 83,
#    'period_end': '2023-03-14T16:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 138,
#    'ghi90': 315,
#    'ghi10': 22,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 138,
#    'air_temp': 3,
#    'zenith': 46,
#    'azimuth': -166,
#    'cloud_opacity': 81,
#    'period_end': '2023-03-14T16:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 147,
#    'ghi90': 343,
#    'ghi10': 22,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 147,
#    'air_temp': 3,
#    'zenith': 45,
#    'azimuth': -177,
#    'cloud_opacity': 80,
#    'period_end': '2023-03-14T17:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 148,
#    'ghi90': 357,
#    'ghi10': 22,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 148,
#    'air_temp': 3,
#    'zenith': 46,
#    'azimuth': 173,
#    'cloud_opacity': 80,
#    'period_end': '2023-03-14T17:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 140,
#    'ghi90': 357,
#    'ghi10': 22,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 140,
#    'air_temp': 3,
#    'zenith': 47,
#    'azimuth': 162,
#    'cloud_opacity': 80,
#    'period_end': '2023-03-14T18:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 130,
#    'ghi90': 343,
#    'ghi10': 21,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 130,
#    'air_temp': 2,
#    'zenith': 49,
#    'azimuth': 153,
#    'cloud_opacity': 81,
#    'period_end': '2023-03-14T18:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 118,
#    'ghi90': 317,
#    'ghi10': 19,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 118,
#    'air_temp': 2,
#    'zenith': 52,
#    'azimuth': 144,
#    'cloud_opacity': 82,
#    'period_end': '2023-03-14T19:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 101,
#    'ghi90': 283,
#    'ghi10': 17,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 101,
#    'air_temp': 2,
#    'zenith': 55,
#    'azimuth': 136,
#    'cloud_opacity': 83,
#    'period_end': '2023-03-14T19:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 84,
#    'ghi90': 247,
#    'ghi10': 15,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 84,
#    'air_temp': 2,
#    'zenith': 59,
#    'azimuth': 128,
#    'cloud_opacity': 84,
#    'period_end': '2023-03-14T20:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 70,
#    'ghi90': 209,
#    'ghi10': 13,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 70,
#    'air_temp': 2,
#    'zenith': 64,
#    'azimuth': 121,
#    'cloud_opacity': 84,
#    'period_end': '2023-03-14T20:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 55,
#    'ghi90': 166,
#    'ghi10': 10,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 55,
#    'air_temp': 2,
#    'zenith': 69,
#    'azimuth': 115,
#    'cloud_opacity': 84,
#    'period_end': '2023-03-14T21:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 38,
#    'ghi90': 119,
#    'ghi10': 7,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 38,
#    'air_temp': 2,
#    'zenith': 74,
#    'azimuth': 109,
#    'cloud_opacity': 85,
#    'period_end': '2023-03-14T21:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 20,
#    'ghi90': 68,
#    'ghi10': 5,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 20,
#    'air_temp': 1,
#    'zenith': 79,
#    'azimuth': 104,
#    'cloud_opacity': 87,
#    'period_end': '2023-03-14T22:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 9,
#    'ghi90': 29,
#    'ghi10': 2,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 9,
#    'air_temp': 1,
#    'zenith': 85,
#    'azimuth': 99,
#    'cloud_opacity': 85,
#    'period_end': '2023-03-14T22:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 1,
#    'ghi90': 3,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 1,
#    'air_temp': 1,
#    'zenith': 90,
#    'azimuth': 94,
#    'cloud_opacity': 78,
#    'period_end': '2023-03-14T23:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 96,
#    'azimuth': 89,
#    'cloud_opacity': 73,
#    'period_end': '2023-03-14T23:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 101,
#    'azimuth': 83,
#    'cloud_opacity': 72,
#    'period_end': '2023-03-15T00:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 107,
#    'azimuth': 78,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T00:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 112,
#    'azimuth': 73,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T01:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 117,
#    'azimuth': 67,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T01:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 122,
#    'azimuth': 60,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T02:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 127,
#    'azimuth': 53,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T02:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 131,
#    'azimuth': 45,
#    'cloud_opacity': 69,
#    'period_end': '2023-03-15T03:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 135,
#    'azimuth': 36,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-15T03:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 137,
#    'azimuth': 26,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-15T04:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 139,
#    'azimuth': 15,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-15T04:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 140,
#    'azimuth': 4,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-15T05:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 140,
#    'azimuth': -8,
#    'cloud_opacity': 69,
#    'period_end': '2023-03-15T05:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 139,
#    'azimuth': -20,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T06:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 136,
#    'azimuth': -30,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T06:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 133,
#    'azimuth': -40,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T07:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 129,
#    'azimuth': -48,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T07:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 125,
#    'azimuth': -56,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T08:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 120,
#    'azimuth': -63,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T08:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 115,
#    'azimuth': -69,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T09:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 110,
#    'azimuth': -75,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T09:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 104,
#    'azimuth': -80,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T10:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 99,
#    'azimuth': -85,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T10:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 93,
#    'azimuth': -90,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T11:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 7,
#    'ghi90': 11,
#    'ghi10': 4,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 7,
#    'air_temp': 0,
#    'zenith': 88,
#    'azimuth': -96,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T11:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 32,
#    'ghi90': 51,
#    'ghi10': 18,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 32,
#    'air_temp': 0,
#    'zenith': 82,
#    'azimuth': -101,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-15T12:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 70,
#    'ghi90': 108,
#    'ghi10': 40,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 70,
#    'air_temp': 0,
#    'zenith': 77,
#    'azimuth': -106,
#    'cloud_opacity': 65,
#    'period_end': '2023-03-15T12:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 108,
#    'ghi90': 166,
#    'ghi10': 64,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 108,
#    'air_temp': 0,
#    'zenith': 72,
#    'azimuth': -111,
#    'cloud_opacity': 64,
#    'period_end': '2023-03-15T13:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 151,
#    'ghi90': 227,
#    'ghi10': 89,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 2,
#    'dhi': 151,
#    'air_temp': 0,
#    'zenith': 67,
#    'azimuth': -117,
#    'cloud_opacity': 62,
#    'period_end': '2023-03-15T13:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 196,
#    'ghi90': 288,
#    'ghi10': 113,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 28,
#    'dhi': 196,
#    'air_temp': 0,
#    'zenith': 62,
#    'azimuth': -124,
#    'cloud_opacity': 59,
#    'period_end': '2023-03-15T14:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 235,
#    'ghi90': 343,
#    'ghi10': 134,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 56,
#    'dhi': 235,
#    'air_temp': 0,
#    'zenith': 58,
#    'azimuth': -131,
#    'cloud_opacity': 58,
#    'period_end': '2023-03-15T14:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 271,
#    'ghi90': 394,
#    'ghi10': 157,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 83,
#    'dhi': 271,
#    'air_temp': 1,
#    'zenith': 54,
#    'azimuth': -139,
#    'cloud_opacity': 57,
#    'period_end': '2023-03-15T15:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 314,
#    'ghi90': 443,
#    'ghi10': 186,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 123,
#    'dhi': 314,
#    'air_temp': 1,
#    'zenith': 50,
#    'azimuth': -147,
#    'cloud_opacity': 54,
#    'period_end': '2023-03-15T15:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 354,
#    'ghi90': 488,
#    'ghi10': 214,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 171,
#    'dhi': 354,
#    'air_temp': 1,
#    'zenith': 48,
#    'azimuth': -156,
#    'cloud_opacity': 51,
#    'period_end': '2023-03-15T16:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 388,
#    'ghi90': 525,
#    'ghi10': 241,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 220,
#    'dhi': 388,
#    'air_temp': 1,
#    'zenith': 46,
#    'azimuth': -166,
#    'cloud_opacity': 49,
#    'period_end': '2023-03-15T16:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 413,
#    'ghi90': 553,
#    'ghi10': 265,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 271,
#    'dhi': 413,
#    'air_temp': 2,
#    'zenith': 45,
#    'azimuth': -177,
#    'cloud_opacity': 46,
#    'period_end': '2023-03-15T17:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 420,
#    'ghi90': 562,
#    'ghi10': 271,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 302,
#    'dhi': 420,
#    'air_temp': 2,
#    'zenith': 45,
#    'azimuth': 173,
#    'cloud_opacity': 45,
#    'period_end': '2023-03-15T17:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 407,
#    'ghi90': 554,
#    'ghi10': 258,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 316,
#    'dhi': 407,
#    'air_temp': 2,
#    'zenith': 46,
#    'azimuth': 162,
#    'cloud_opacity': 45,
#    'period_end': '2023-03-15T18:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 385,
#    'ghi90': 532,
#    'ghi10': 238,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 324,
#    'dhi': 385,
#    'air_temp': 2,
#    'zenith': 49,
#    'azimuth': 153,
#    'cloud_opacity': 46,
#    'period_end': '2023-03-15T18:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 353,
#    'ghi90': 499,
#    'ghi10': 211,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 325,
#    'dhi': 353,
#    'air_temp': 3,
#    'zenith': 51,
#    'azimuth': 144,
#    'cloud_opacity': 47,
#    'period_end': '2023-03-15T19:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 311,
#    'ghi90': 456,
#    'ghi10': 179,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 330,
#    'dhi': 311,
#    'air_temp': 3,
#    'zenith': 55,
#    'azimuth': 135,
#    'cloud_opacity': 48,
#    'period_end': '2023-03-15T19:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 265,
#    'ghi90': 402,
#    'ghi10': 150,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 323,
#    'dhi': 265,
#    'air_temp': 3,
#    'zenith': 59,
#    'azimuth': 128,
#    'cloud_opacity': 50,
#    'period_end': '2023-03-15T20:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 219,
#    'ghi90': 339,
#    'ghi10': 121,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 309,
#    'dhi': 219,
#    'air_temp': 3,
#    'zenith': 64,
#    'azimuth': 121,
#    'cloud_opacity': 51,
#    'period_end': '2023-03-15T20:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 167,
#    'ghi90': 266,
#    'ghi10': 89,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 271,
#    'dhi': 167,
#    'air_temp': 3,
#    'zenith': 69,
#    'azimuth': 115,
#    'cloud_opacity': 53,
#    'period_end': '2023-03-15T21:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 116,
#    'ghi90': 192,
#    'ghi10': 58,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 228,
#    'dhi': 116,
#    'air_temp': 3,
#    'zenith': 74,
#    'azimuth': 109,
#    'cloud_opacity': 55,
#    'period_end': '2023-03-15T21:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 65,
#    'ghi90': 114,
#    'ghi10': 31,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 116,
#    'dhi': 65,
#    'air_temp': 3,
#    'zenith': 79,
#    'azimuth': 104,
#    'cloud_opacity': 59,
#    'period_end': '2023-03-15T22:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 26,
#    'ghi90': 47,
#    'ghi10': 11,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 11,
#    'dhi': 26,
#    'air_temp': 2,
#    'zenith': 84,
#    'azimuth': 98,
#    'cloud_opacity': 63,
#    'period_end': '2023-03-15T22:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 3,
#    'ghi90': 5,
#    'ghi10': 1,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 3,
#    'air_temp': 2,
#    'zenith': 90,
#    'azimuth': 93,
#    'cloud_opacity': 62,
#    'period_end': '2023-03-15T23:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 96,
#    'azimuth': 88,
#    'cloud_opacity': 62,
#    'period_end': '2023-03-15T23:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 101,
#    'azimuth': 83,
#    'cloud_opacity': 62,
#    'period_end': '2023-03-16T00:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 107,
#    'azimuth': 78,
#    'cloud_opacity': 62,
#    'period_end': '2023-03-16T00:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 112,
#    'azimuth': 72,
#    'cloud_opacity': 60,
#    'period_end': '2023-03-16T01:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 117,
#    'azimuth': 66,
#    'cloud_opacity': 59,
#    'period_end': '2023-03-16T01:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 122,
#    'azimuth': 60,
#    'cloud_opacity': 57,
#    'period_end': '2023-03-16T02:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 127,
#    'azimuth': 53,
#    'cloud_opacity': 56,
#    'period_end': '2023-03-16T02:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 131,
#    'azimuth': 45,
#    'cloud_opacity': 55,
#    'period_end': '2023-03-16T03:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 134,
#    'azimuth': 36,
#    'cloud_opacity': 54,
#    'period_end': '2023-03-16T03:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 137,
#    'azimuth': 26,
#    'cloud_opacity': 51,
#    'period_end': '2023-03-16T04:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 139,
#    'azimuth': 15,
#    'cloud_opacity': 48,
#    'period_end': '2023-03-16T04:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 140,
#    'azimuth': 3,
#    'cloud_opacity': 44,
#    'period_end': '2023-03-16T05:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 140,
#    'azimuth': -8,
#    'cloud_opacity': 38,
#    'period_end': '2023-03-16T05:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 138,
#    'azimuth': -19,
#    'cloud_opacity': 31,
#    'period_end': '2023-03-16T06:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 136,
#    'azimuth': -30,
#    'cloud_opacity': 25,
#    'period_end': '2023-03-16T06:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 0,
#    'zenith': 133,
#    'azimuth': -39,
#    'cloud_opacity': 22,
#    'period_end': '2023-03-16T07:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
# ...
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 6,
#    'zenith': 124,
#    'azimuth': -55,
#    'cloud_opacity': 76,
#    'period_end': '2023-03-18T08:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 6,
#    'zenith': 119,
#    'azimuth': -62,
#    'cloud_opacity': 77,
#    'period_end': '2023-03-18T08:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 6,
#    'zenith': 114,
#    'azimuth': -68,
#    'cloud_opacity': 78,
#    'period_end': '2023-03-18T09:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 6,
#    'zenith': 109,
#    'azimuth': -74,
#    'cloud_opacity': 78,
#    'period_end': '2023-03-18T09:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 6,
#    'zenith': 104,
#    'azimuth': -79,
#    'cloud_opacity': 78,
#    'period_end': '2023-03-18T10:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 6,
#    'zenith': 98,
#    'azimuth': -85,
#    'cloud_opacity': 78,
#    'period_end': '2023-03-18T10:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 6,
#    'zenith': 92,
#    'azimuth': -90,
#    'cloud_opacity': 78,
#    'period_end': '2023-03-18T11:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 6,
#    'ghi90': 25,
#    'ghi10': 1,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 37,
#    'dhi': 6,
#    'air_temp': 6,
#    'zenith': 87,
#    'azimuth': -95,
#    'cloud_opacity': 79,
#    'period_end': '2023-03-18T11:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 24,
#    'ghi90': 90,
#    'ghi10': 3,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 211,
#    'dhi': 24,
#    'air_temp': 6,
#    'zenith': 81,
#    'azimuth': -100,
#    'cloud_opacity': 78,
#    'period_end': '2023-03-18T12:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 50,
#    'ghi90': 175,
#    'ghi10': 6,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 395,
#    'dhi': 50,
#    'air_temp': 6,
#    'zenith': 76,
#    'azimuth': -105,
#    'cloud_opacity': 74,
#    'period_end': '2023-03-18T12:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 75,
#    'ghi90': 251,
#    'ghi10': 9,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 419,
#    'dhi': 75,
#    'air_temp': 6,
#    'zenith': 71,
#    'azimuth': -111,
#    'cloud_opacity': 74,
#    'period_end': '2023-03-18T13:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 100,
#    'ghi90': 324,
#    'ghi10': 11,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 433,
#    'dhi': 100,
#    'air_temp': 6,
#    'zenith': 66,
#    'azimuth': -117,
#    'cloud_opacity': 74,
#    'period_end': '2023-03-18T13:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 124,
#    'ghi90': 394,
#    'ghi10': 14,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 457,
#    'dhi': 124,
#    'air_temp': 6,
#    'zenith': 61,
#    'azimuth': -123,
#    'cloud_opacity': 73,
#    'period_end': '2023-03-18T14:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 139,
#    'ghi90': 450,
#    'ghi10': 16,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 446,
#    'dhi': 139,
#    'air_temp': 6,
#    'zenith': 56,
#    'azimuth': -130,
#    'cloud_opacity': 74,
#    'period_end': '2023-03-18T14:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 151,
#    'ghi90': 486,
#    'ghi10': 18,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 392,
#    'dhi': 151,
#    'air_temp': 7,
#    'zenith': 52,
#    'azimuth': -138,
#    'cloud_opacity': 75,
#    'period_end': '2023-03-18T15:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 167,
#    'ghi90': 518,
#    'ghi10': 20,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 367,
#    'dhi': 167,
#    'air_temp': 7,
#    'zenith': 49,
#    'azimuth': -147,
#    'cloud_opacity': 75,
#    'period_end': '2023-03-18T15:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 185,
#    'ghi90': 548,
#    'ghi10': 21,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 370,
#    'dhi': 185,
#    'air_temp': 7,
#    'zenith': 46,
#    'azimuth': -156,
#    'cloud_opacity': 74,
#    'period_end': '2023-03-18T16:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 195,
#    'ghi90': 570,
#    'ghi10': 22,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 376,
#    'dhi': 195,
#    'air_temp': 7,
#    'zenith': 45,
#    'azimuth': -166,
#    'cloud_opacity': 73,
#    'period_end': '2023-03-18T16:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 195,
#    'ghi90': 582,
#    'ghi10': 22,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 387,
#    'dhi': 195,
#    'air_temp': 7,
#    'zenith': 44,
#    'azimuth': -177,
#    'cloud_opacity': 74,
#    'period_end': '2023-03-18T17:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 190,
#    'ghi90': 580,
#    'ghi10': 22,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 389,
#    'dhi': 190,
#    'air_temp': 7,
#    'zenith': 44,
#    'azimuth': 172,
#    'cloud_opacity': 74,
#    'period_end': '2023-03-18T17:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 179,
#    'ghi90': 566,
#    'ghi10': 22,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 386,
#    'dhi': 179,
#    'air_temp': 7,
#    'zenith': 45,
#    'azimuth': 162,
#    'cloud_opacity': 75,
#    'period_end': '2023-03-18T18:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 167,
#    'ghi90': 549,
#    'ghi10': 21,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 408,
#    'dhi': 167,
#    'air_temp': 7,
#    'zenith': 47,
#    'azimuth': 152,
#    'cloud_opacity': 76,
#    'period_end': '2023-03-18T18:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 157,
#    'ghi90': 529,
#    'ghi10': 19,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 460,
#    'dhi': 157,
#    'air_temp': 7,
#    'zenith': 50,
#    'azimuth': 143,
#    'cloud_opacity': 75,
#    'period_end': '2023-03-18T19:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 136,
#    'ghi90': 495,
#    'ghi10': 17,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 503,
#    'dhi': 136,
#    'air_temp': 6,
#    'zenith': 54,
#    'azimuth': 134,
#    'cloud_opacity': 77,
#    'period_end': '2023-03-18T19:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 112,
#    'ghi90': 436,
#    'ghi10': 15,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 492,
#    'dhi': 112,
#    'air_temp': 6,
#    'zenith': 58,
#    'azimuth': 127,
#    'cloud_opacity': 78,
#    'period_end': '2023-03-18T20:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 96,
#    'ghi90': 377,
#    'ghi10': 13,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 512,
#    'dhi': 96,
#    'air_temp': 6,
#    'zenith': 63,
#    'azimuth': 120,
#    'cloud_opacity': 78,
#    'period_end': '2023-03-18T20:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 80,
#    'ghi90': 315,
#    'ghi10': 10,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 569,
#    'dhi': 80,
#    'air_temp': 6,
#    'zenith': 68,
#    'azimuth': 114,
#    'cloud_opacity': 77,
#    'period_end': '2023-03-18T21:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 57,
#    'ghi90': 240,
#    'ghi10': 7,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 590,
#    'dhi': 57,
#    'air_temp': 6,
#    'zenith': 73,
#    'azimuth': 108,
#    'cloud_opacity': 77,
#    'period_end': '2023-03-18T21:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 32,
#    'ghi90': 150,
#    'ghi10': 5,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 463,
#    'dhi': 32,
#    'air_temp': 6,
#    'zenith': 78,
#    'azimuth': 103,
#    'cloud_opacity': 80,
#    'period_end': '2023-03-18T22:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 13,
#    'ghi90': 65,
#    'ghi10': 2,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 241,
#    'dhi': 13,
#    'air_temp': 6,
#    'zenith': 84,
#    'azimuth': 97,
#    'cloud_opacity': 80,
#    'period_end': '2023-03-18T22:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 2,
#    'ghi90': 8,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 20,
#    'dhi': 2,
#    'air_temp': 5,
#    'zenith': 89,
#    'azimuth': 92,
#    'cloud_opacity': 76,
#    'period_end': '2023-03-18T23:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 95,
#    'azimuth': 87,
#    'cloud_opacity': 74,
#    'period_end': '2023-03-18T23:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 100,
#    'azimuth': 82,
#    'cloud_opacity': 72,
#    'period_end': '2023-03-19T00:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 106,
#    'azimuth': 77,
#    'cloud_opacity': 70,
#    'period_end': '2023-03-19T00:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 111,
#    'azimuth': 71,
#    'cloud_opacity': 68,
#    'period_end': '2023-03-19T01:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 116,
#    'azimuth': 65,
#    'cloud_opacity': 65,
#    'period_end': '2023-03-19T01:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 121,
#    'azimuth': 59,
#    'cloud_opacity': 63,
#    'period_end': '2023-03-19T02:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 126,
#    'azimuth': 52,
#    'cloud_opacity': 60,
#    'period_end': '2023-03-19T02:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 130,
#    'azimuth': 44,
#    'cloud_opacity': 57,
#    'period_end': '2023-03-19T03:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 133,
#    'azimuth': 35,
#    'cloud_opacity': 53,
#    'period_end': '2023-03-19T03:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 136,
#    'azimuth': 25,
#    'cloud_opacity': 49,
#    'period_end': '2023-03-19T04:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 138,
#    'azimuth': 14,
#    'cloud_opacity': 45,
#    'period_end': '2023-03-19T04:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 139,
#    'azimuth': 3,
#    'cloud_opacity': 40,
#    'period_end': '2023-03-19T05:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 138,
#    'azimuth': -8,
#    'cloud_opacity': 36,
#    'period_end': '2023-03-19T05:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 137,
#    'azimuth': -19,
#    'cloud_opacity': 33,
#    'period_end': '2023-03-19T06:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 5,
#    'zenith': 135,
#    'azimuth': -30,
#    'cloud_opacity': 31,
#    'period_end': '2023-03-19T06:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 132,
#    'azimuth': -39,
#    'cloud_opacity': 30,
#    'period_end': '2023-03-19T07:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 4,
#    'zenith': 128,
#    'azimuth': -47,
#    'cloud_opacity': 29,
#    'period_end': '2023-03-19T07:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 124,
#    'azimuth': -55,
#    'cloud_opacity': 28,
#    'period_end': '2023-03-19T08:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 3,
#    'zenith': 119,
#    'azimuth': -62,
#    'cloud_opacity': 26,
#    'period_end': '2023-03-19T08:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 114,
#    'azimuth': -68,
#    'cloud_opacity': 26,
#    'period_end': '2023-03-19T09:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 109,
#    'azimuth': -74,
#    'cloud_opacity': 24,
#    'period_end': '2023-03-19T09:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 103,
#    'azimuth': -79,
#    'cloud_opacity': 23,
#    'period_end': '2023-03-19T10:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 2,
#    'zenith': 98,
#    'azimuth': -84,
#    'cloud_opacity': 21,
#    'period_end': '2023-03-19T10:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 0,
#    'ghi90': 0,
#    'ghi10': 0,
#    'ebh': 0,
#    'dni': 0,
#    'dni10': 0,
#    'dni90': 0,
#    'dhi': 0,
#    'air_temp': 1,
#    'zenith': 92,
#    'azimuth': -89,
#    'cloud_opacity': 20,
#    'period_end': '2023-03-19T11:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 29,
#    'ghi90': 35,
#    'ghi10': 5,
#    'ebh': 3,
#    'dni': 31,
#    'dni10': 0,
#    'dni90': 164,
#    'dhi': 26,
#    'air_temp': 1,
#    'zenith': 87,
#    'azimuth': -95,
#    'cloud_opacity': 18,
#    'period_end': '2023-03-19T11:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 101,
#    'ghi90': 117,
#    'ghi10': 18,
#    'ebh': 38,
#    'dni': 230,
#    'dni10': 0,
#    'dni90': 457,
#    'dhi': 64,
#    'air_temp': 1,
#    'zenith': 81,
#    'azimuth': -100,
#    'cloud_opacity': 14,
#    'period_end': '2023-03-19T12:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 204,
#    'ghi90': 212,
#    'ghi10': 43,
#    'ebh': 131,
#    'dni': 523,
#    'dni10': 0,
#    'dni90': 604,
#    'dhi': 73,
#    'air_temp': 1,
#    'zenith': 76,
#    'azimuth': -105,
#    'cloud_opacity': 4,
#    'period_end': '2023-03-19T12:30:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 309,
#    'ghi90': 310,
#    'ghi10': 75,
#    'ebh': 233,
#    'dni': 693,
#    'dni10': 0,
#    'dni90': 705,
#    'dhi': 76,
#    'air_temp': 2,
#    'zenith': 70,
#    'azimuth': -111,
#    'cloud_opacity': 0,
#    'period_end': '2023-03-19T13:00:00.0000000Z',
#    'period': 'PT30M'},
#   {'ghi': 407,
#    'ghi90': 407,
#    'ghi10': 111,
#    'ebh': 326,
#    'dni': 781,
#    'dni10': 0,
#    'dni90': 781,
#    'dhi': 81,
#    'air_temp': 2,
#    'zenith': 65,
#    'azimuth': -116,
#    'cloud_opacity': 0,
#    'period_end': '2023-03-19T13:30:00.0000000Z',
#    'period': 'PT30M'}]}

# %% [markdown]
# # Step - 2 Exploring the json using keys() and type() function
#
# #### Explore how many dict are listed from keys. Explore the types for all dict. Since we have only one dict we are doing once.

# %%
import pandas as pd
import json

# %%
response.keys()
# Out:
# dict_keys(['forecasts'])

# %%
type(response['forecasts'][0])
# Out:
# dict

# %% [markdown]
# # Step 3 - Json to dataframe
#
# ### We have got a list of dict from the previous step. Only select the dict which are of type lists

# %%
df = pd.DataFrame(response['forecasts'])

# %%
df
# Out:
#      ghi  ghi90  ghi10  ebh  dni  dni10  dni90  dhi  air_temp  zenith  \
# 0    286    353    250  111  288    115    690  175         1      68
# 1    434    464    329  327  715    203    891  107         2      63
# 2    544    544    461  480  923    519    923   64         2      59
# 3    614    614    570  547  948    747    948   67         3      55
# 4    668    671    552  595  954    493    966   73         3      51
# ..   ...    ...    ...  ...  ...    ...    ...  ...       ...     ...
# 332   29     35      5    3   31      0    164   26         1      87
# 333  101    117     18   38  230      0    457   64         1      81
# 334  204    212     43  131  523      0    604   73         1      76
# 335  309    310     75  233  693      0    705   76         2      70
# 336  407    407    111  326  781      0    781   81         2      65
#
#      azimuth  cloud_opacity                    period_end period
# 0       -118             24  2023-03-12T13:30:00.0000000Z  PT30M
# 1       -124              7  2023-03-12T14:00:00.0000000Z  PT30M
# 2       -131              0  2023-03-12T14:30:00.0000000Z  PT30M
# 3       -139              0  2023-03-12T15:00:00.0000000Z  PT30M
# 4       -147              0  2023-03-12T15:30:00.0000000Z  PT30M
# ..       ...            ...                           ...    ...
# 332      -95             18  2023-03-19T11:30:00.0000000Z  PT30M
# 333     -100             14  2023-03-19T12:00:00.0000000Z  PT30M
# 334     -105              4  2023-03-19T12:30:00.0000000Z  PT30M
# 335     -111              0  2023-03-19T13:00:00.0000000Z  PT30M
# 336     -116              0  2023-03-19T13:30:00.0000000Z  PT30M
#
# [337 rows x 14 columns]

# %% [markdown]
# # Data cleaning

# %%
# Rename columns
column_names = {'ghi': 'Global Horizontal Irradiance', 'ghi90':'GHI for 90 degree plane of array','ghi10':'GHI for 10 degree plane of array', 'ebh':'Extraterrestrial Horizontal Irradiance','dhi': 'Diffuse Horizontal Irradiance', 'dni10': 'DNI for 10 degree plane of array',
'dni90': 'DNI for 90 degree plane of array','dni': 'Direct Normal Irradiance', 'air_temp': 'Air Temperature', 'zenith': 'Zenith Angle', 'azimuth': 'Azimuth Angle'}
df.rename(columns=column_names, inplace=True)

# %%
df
# Out:
#      Global Horizontal Irradiance  GHI for 90 degree plane of array  \
# 0                             286                               353
# 1                             434                               464
# 2                             544                               544
# 3                             614                               614
# 4                             668                               671
# ..                            ...                               ...
# 332                            29                                35
# 333                           101                               117
# 334                           204                               212
# 335                           309                               310
# 336                           407                               407
#
#      GHI for 10 degree plane of array  Extraterrestrial Horizontal Irradiance  \
# 0                                 250                                     111
# 1                                 329                                     327
# 2                                 461                                     480
# 3                                 570                                     547
# 4                                 552                                     595
# ..                                ...                                     ...
# 332                                 5                                       3
# 333                                18                                      38
# 334                                43                                     131
# 335                                75                                     233
# 336                               111                                     326
#
#      Direct Normal Irradiance  DNI for 10 degree plane of array  \
# 0                         288                               115
# 1                         715                               203
# 2                         923                               519
# 3                         948                               747
# 4                         954                               493
# ..                        ...                               ...
# 332                        31                                 0
# 333                       230                                 0
# 334                       523                                 0
# 335                       693                                 0
# 336                       781                                 0
#
#      DNI for 90 degree plane of array  Diffuse Horizontal Irradiance  \
# 0                                 690                            175
# 1                                 891                            107
# 2                                 923                             64
# 3                                 948                             67
# 4                                 966                             73
# ..                                ...                            ...
# 332                               164                             26
# 333                               457                             64
# 334                               604                             73
# 335                               705                             76
# 336                               781                             81
#
#      Air Temperature  Zenith Angle  Azimuth Angle  cloud_opacity  \
# 0                  1            68           -118             24
# 1                  2            63           -124              7
# 2                  2            59           -131              0
# 3                  3            55           -139              0
# 4                  3            51           -147              0
# ..               ...           ...            ...            ...
# 332                1            87            -95             18
# 333                1            81           -100             14
# 334                1            76           -105              4
# 335                2            70           -111              0
# 336                2            65           -116              0
#
#                        period_end period
# 0    2023-03-12T13:30:00.0000000Z  PT30M
# 1    2023-03-12T14:00:00.0000000Z  PT30M
# 2    2023-03-12T14:30:00.0000000Z  PT30M
# 3    2023-03-12T15:00:00.0000000Z  PT30M
# 4    2023-03-12T15:30:00.0000000Z  PT30M
# ..                            ...    ...
# 332  2023-03-19T11:30:00.0000000Z  PT30M
# 333  2023-03-19T12:00:00.0000000Z  PT30M
# 334  2023-03-19T12:30:00.0000000Z  PT30M
# 335  2023-03-19T13:00:00.0000000Z  PT30M
# 336  2023-03-19T13:30:00.0000000Z  PT30M
#
# [337 rows x 14 columns]

# %%
# Check for missing data
print(df.isnull().sum())

# Drop rows with missing data
df.dropna(inplace=True)
# Out:
# Global Horizontal Irradiance              0
# GHI for 90 degree plane of array          0
# GHI for 10 degree plane of array          0
# Extraterrestrial Horizontal Irradiance    0
# Direct Normal Irradiance                  0
# DNI for 10 degree plane of array          0
# DNI for 90 degree plane of array          0
# Diffuse Horizontal Irradiance             0
# Air Temperature                           0
# Zenith Angle                              0
# Azimuth Angle                             0
# cloud_opacity                             0
# period_end                                0
# period                                    0
# dtype: int64

# %%
# Count of missing values for each column
print(df.isnull().sum())
# Out:
# Global Horizontal Irradiance              0
# GHI for 90 degree plane of array          0
# GHI for 10 degree plane of array          0
# Extraterrestrial Horizontal Irradiance    0
# Direct Normal Irradiance                  0
# DNI for 10 degree plane of array          0
# DNI for 90 degree plane of array          0
# Diffuse Horizontal Irradiance             0
# Air Temperature                           0
# Zenith Angle                              0
# Azimuth Angle                             0
# cloud_opacity                             0
# period_end                                0
# period                                    0
# dtype: int64

# %%
df['period_end'] = pd.to_datetime(df['period_end'])

# %%
df
# Out:
#      Global Horizontal Irradiance  GHI for 90 degree plane of array  \
# 0                             286                               353
# 1                             434                               464
# 2                             544                               544
# 3                             614                               614
# 4                             668                               671
# ..                            ...                               ...
# 332                            29                                35
# 333                           101                               117
# 334                           204                               212
# 335                           309                               310
# 336                           407                               407
#
#      GHI for 10 degree plane of array  Extraterrestrial Horizontal Irradiance  \
# 0                                 250                                     111
# 1                                 329                                     327
# 2                                 461                                     480
# 3                                 570                                     547
# 4                                 552                                     595
# ..                                ...                                     ...
# 332                                 5                                       3
# 333                                18                                      38
# 334                                43                                     131
# 335                                75                                     233
# 336                               111                                     326
#
#      Direct Normal Irradiance  DNI for 10 degree plane of array  \
# 0                         288                               115
# 1                         715                               203
# 2                         923                               519
# 3                         948                               747
# 4                         954                               493
# ..                        ...                               ...
# 332                        31                                 0
# 333                       230                                 0
# 334                       523                                 0
# 335                       693                                 0
# 336                       781                                 0
#
#      DNI for 90 degree plane of array  Diffuse Horizontal Irradiance  \
# 0                                 690                            175
# 1                                 891                            107
# 2                                 923                             64
# 3                                 948                             67
# 4                                 966                             73
# ..                                ...                            ...
# 332                               164                             26
# 333                               457                             64
# 334                               604                             73
# 335                               705                             76
# 336                               781                             81
#
#      Air Temperature  Zenith Angle  Azimuth Angle  cloud_opacity  \
# 0                  1            68           -118             24
# 1                  2            63           -124              7
# 2                  2            59           -131              0
# 3                  3            55           -139              0
# 4                  3            51           -147              0
# ..               ...           ...            ...            ...
# 332                1            87            -95             18
# 333                1            81           -100             14
# 334                1            76           -105              4
# 335                2            70           -111              0
# 336                2            65           -116              0
#
#                    period_end period
# 0   2023-03-12 13:30:00+00:00  PT30M
# 1   2023-03-12 14:00:00+00:00  PT30M
# 2   2023-03-12 14:30:00+00:00  PT30M
# 3   2023-03-12 15:00:00+00:00  PT30M
# 4   2023-03-12 15:30:00+00:00  PT30M
# ..                        ...    ...
# 332 2023-03-19 11:30:00+00:00  PT30M
# 333 2023-03-19 12:00:00+00:00  PT30M
# 334 2023-03-19 12:30:00+00:00  PT30M
# 335 2023-03-19 13:00:00+00:00  PT30M
# 336 2023-03-19 13:30:00+00:00  PT30M
#
# [337 rows x 14 columns]

# %% [markdown]
# # Step 3 - Connecting the datas from pandas to sql

# %% [markdown]
# ## First create a database in sql
# CREATE DATABASE mydata;

# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in c:\users\adhir\anaconda3\lib\site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql

# %%
from sqlalchemy import create_engine
# connect to the MySQL database
engine = create_engine('mysql+pymysql://root:root@localhost/mydata')

# %%
#Write the data to the database: You can use the to_sql method of your Pandas DataFrame to write the data to a table in your database
df.to_sql('mytable', con=engine, if_exists='replace', index=False)
# Out:
# 337

# %% [markdown]
# #### This means that df has been importen in sql

# %% [markdown]
# # SQL Query
# ## Do some filtering. Filtered datas are stored in seperate tables
#
# ### This filtering is important if you want to focus on times when there is enough sunlight to generate significant amounts of energy. A GHI value of 50 or above is generally considered sufficient for solar energy production.
# CREATE TABLE ghi_50_SE_production AS
# select * from mytable
#  WHERE `Global Horizontal Irradiance` > 50;
#
#  ### This query will return all rows where the time of day is between 9:00 AM and 5:00 PM. This filtering is important because solar energy production is highest during daylight hours, so you may want to focus on data from this time period.
# drop table if exists time_with_max_sunlight;
# create table time_with_max_sunlight as
# SELECT *
# FROM mytable
# WHERE TIME(period_end) BETWEEN '09:00:00' AND '16:00:00';
#
# ### Clouds can significantly reduce solar energy production, so this filtering can help you identify times when there were clear skies and optimal energy production conditions.
# drop table if exists low_cloud_opacity;
# create table low_cloud_opacity as
#  SELECT * FROM mytable WHERE cloud_opacity < 50;
